# %%
# lab tech


# MOST CODE ARE PLACEHOLDER UNTIL VIEW MAIN MODULES....

# Give me feedback on anything i missed...

class LabTech:
    def __init__(self, uid, password, first, last):
        self.uid = pid
        self.password = password
        self.first = first_name
        self.last = last_name

class HIS:
    # the users?
    def __init__(self):
        self.patients = {}
        self.doctors = {}
        self.nurses = {}
        self.lab_tech = {}

    # Lab Tech menu... choices 
    def lab_tech_module(self):
        uid = input("Enter Lab Tech ID: ")
        pwd = getpass.getpass("Enter Password: ")
        tech = self.lab_tech.get(uid)
        if not tech or tech.password != pwd:
            print("Login Failed.")
            return
        
        while True:
            print("\nLab Technician Menu: ")
            print("1. View Assigned Lab Tests")
            print("2. Edit Lab test")
            print("3. Back to Main Menu")
            selected_choice = input("Select option: ")
            pass
            if selected_choice == "1":
                self.view_all_lab_tests()
            elif selected_choice == "2":
                self.edit_lab_test()
            elif selected_choice == "3":
                break
                
    # PLACEMENT FUNCTION HOLDER..... need to check other code to understand...
    def view_all_lab_tests(self):
        print("......All Lab Tests......")
        for pid, patient in self.patients.items():  # key/item in patients if the patienst stored in dict
            labs = patient.get_lab_tests()
            if labs:
                print(f"\n{patient.first}{patient.last}(ID: {pid})") # place holder
                for item, cost in labs:
                    print(f"--{item}: $z{cost:.2f}") # place holders...
            
    # EDITS LAB TEST NAME AND COSTS
    def edit_lab_tests(self):
        pid = input("Enter Patient ID: ")
        patient = self.patients.get(pid) # what ever patient value is get from...
        if not patient:
            print("Patient not found")
            return
        old_lab_name = input("Enter the existing lab test name to edit: ")
        new_lab_name = input("New Lab Test Name: ")
        try:
            new_cost = float(input("New Cost: "))
            updated = patient.update_lab_test(old_name, new_name, new_cost)
            if updated:
                print("Lab test updated.")
            else:
                print("Lab test not found")
        except ValueError:
            print("Invalid cost. Try Again")


            

# NEED MAIN FUNCTION TO RUN
# Need to check other mandatory modules to make the rest line up with code....
